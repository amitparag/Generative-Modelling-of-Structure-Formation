# %%
import warnings
warnings.simplefilter("ignore", UserWarning)
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('train.csv')

df['Subhalo Distribution, between redshifts 1.74 and 3.02'] = df['NumberOfSubhalos']
df['Halo Group_M_Crit_200, between redshifts 1.74 and 3.02'] = df['haloVirialMass']
df['Halo Group_R_Crit_200, between redshifts 1.74 and 3.02'] = df['haloVirialRadius']
h = sns.pairplot(data=df,y_vars=['Subhalo Distribution, between redshifts 1.74 and 3.02'], \
               x_vars=['Halo Group_M_Crit_200, between redshifts 1.74 and 3.02', \
                       'Halo Group_R_Crit_200, between redshifts 1.74 and 3.02'], \
              kind="scatter", markers = '.', plot_kws=dict(alpha = 0.6, s= 80,
                edgecolor='#dff7be'))

h.fig.set_size_inches(20,15)
#h.savefig("pastSnapShot.png")
'''
dff = pd.read_csv('test.csv')


dff['Number of Subhalos, present day'] = dff['testfofsubhalos']
dff['Halo Group_M_Crit_200, present day'] = dff['testfofVirialMass']
dff['Halo Group_R_Crit_200, present day'] = dff['testfofVirialRadius']
g = sns.pairplot(data=dff,y_vars=['Number of Subhalos, present day'], \
               x_vars=['Halo Group_M_Crit_200, present day', 'Halo Group_R_Crit_200, present day'], \
              kind="scatter", markers = '.', plot_kws=dict(alpha = 0.6, s= 80,
                edgecolor='#dff7be'))

g.fig.set_size_inches(20,10)
g.savefig("presentSnapShot.png")

'''
# Out:
# '\ndff = pd.read_csv(\'test.csv\')\n\n\ndff[\'Number of Subhalos, present day\'] = dff[\'testfofsubhalos\']\ndff[\'Halo Group_M_Crit_200, present day\'] = dff[\'testfofVirialMass\']\ndff[\'Halo Group_R_Crit_200, present day\'] = dff[\'testfofVirialRadius\']\ng = sns.pairplot(data=dff,y_vars=[\'Number of Subhalos, present day\'],                x_vars=[\'Halo Group_M_Crit_200, present day\', \'Halo Group_R_Crit_200, present day\'],               kind="scatter", markers = \'.\', plot_kws=dict(alpha = 0.6, s= 80,\n                edgecolor=\'#dff7be\'))\n\ng.fig.set_size_inches(20,10)\ng.savefig("presentSnapShot.png")\n\n'
